# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Простейшие формулы производных

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MSE
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Возрастание и убывание функции

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Пример минимизации функции потерь с двумя весами
# ![image.png](attachment:image.png)
