# %% [markdown]
# ### В задаче многоклассовой классификации после последнего слоя стоит использовать функцию активации Softmax (вероятность в пределах 0-1 и сумма равняется 1).
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Для бинарной классификации (multi-label классификации) нам подойдет Сигмоида на последнем слое в роли функции активации.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ### Усреднение проводится по классам (C) и по батчам (batch size).

# %% [markdown]
# ![image.png](attachment:image.png)
