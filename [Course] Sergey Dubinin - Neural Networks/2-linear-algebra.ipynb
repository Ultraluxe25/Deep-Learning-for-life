# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# #### Результатом обоих действий будет число (скаляр)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Линейный слой нейронной сети, где `x` - входные данные, а `W.T` и `b` - обучаемые параметры.

# %% [markdown]
# ![image.png](attachment:image.png)
