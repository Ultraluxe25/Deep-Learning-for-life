# %% [markdown]
# # 2.1 Подготовка данных. Dataset и DataLoader. часть 1

# %% [markdown]
# ![image.png](attachment:9c38cdb6-acd1-4483-b39e-88f0f05555ad.png)

# %% [markdown]
# ![image.png](attachment:cb083581-9c32-49dc-b5b4-d1b0bdfec676.png)
# ### Для классификации удобнее в таком формате (отдельной папки)

# %% [markdown]
# ![image.png](attachment:2781142e-90a7-4c2a-abdf-357c4199546d.png)
# ### А вот так удобно для задач сегментации

# %% [markdown]
# ### Худшее что можно сделать при несбалансированных классах - это просто размножить объекты малого класса, а не применять аугментацию

# %% [markdown]
# ![image.png](attachment:2373624c-16c4-433d-9e2b-49f8ce6aee10.png)
# ### __getitem__ позволяет по индексу датасета получить его объект и таргет

# %% [markdown]
# ![image.png](attachment:57665e4f-7a97-481c-a8a2-54ba3c745045.png)
# ### Разбиваем датасет на батчи для обучения с помощью DataLoader
# ![image.png](attachment:ee5e80b2-eea3-4719-8b42-30fd2535e4f3.png)

# %% [markdown]
# ![image.png](attachment:60920756-be26-4a3b-b128-ce9763caafec.png)

# %% [markdown]
# ![image.png](attachment:d0e7404b-266f-4f21-87c3-eafaa9f78bf6.png)

# %% [markdown]
# ![image.png](attachment:d9d8bab6-ef37-4b95-ba80-e745a521d89a.png)

# %% [markdown]
# ![image.png](attachment:4b463ec8-dd44-45c6-8bff-9cba2bef924c.png)

# %% [markdown]
# ![image.png](attachment:64d411b5-00ed-4ece-87bf-e42b34cd9de2.png)

# %% [markdown]
# ![image.png](attachment:eb5a448f-1edb-48f1-a8ac-a46a94ef6a5d.png)

# %% [markdown]
# ![image.png](attachment:3713e3f9-2042-40df-99e2-e8a7261d510e.png)
