# %% [markdown]
# ## Task 1

# %% [markdown]
# ![image.png](attachment:aaf90434-469c-450c-8b40-1c0392628bc9.png)

# %% [markdown]
# ## Task 2

# %% [markdown]
# ![image.png](attachment:ff9ad2b2-5fa0-475c-9ac3-4776211e2f1f.png)

# %% [markdown]
# ## Task 3

# %% [markdown]
# ![image.png](attachment:1e4e6f7f-efd3-49a6-8de0-e514bf1e99a2.png)

# %% [markdown]
# ## Task 4
# ![image.png](attachment:da165e04-01d3-4dbc-a952-7b6aa3a1d31e.png)

# %% [markdown]
# ## Task 5

# %% [markdown]
# ![image.png](attachment:11cc250b-d450-462d-ad17-91377de7b7a8.png)

# %% [markdown]
# ![image.png](attachment:2387fda7-722b-4395-a2a7-bc7d34c941a9.png)

# %% [markdown]
# ![image.png](attachment:e67d05a8-118b-43f0-afea-893325289dfa.png)

# %% [markdown]
# ## Task 6
# ![image.png](attachment:b5d1b4d9-4a40-4121-974c-17fa6647a6f7.png)

# %% [markdown]
# ## Task 7
# ![image.png](attachment:8d33c908-84ad-4001-b950-ace073ef1dfc.png)

# %% [markdown]
# ## Task 8
# ![image.png](attachment:91259a15-ef65-4fb7-9e71-45461d22e340.png)

# %% [markdown]
# ## Task 9
# ![image.png](attachment:5973146f-3caf-473c-a9c7-5f6da3d0b0b4.png)

# %% [markdown]
# ## Task 10
# ![image.png](attachment:5f26f4ea-040f-4252-abad-a3fef0ecc814.png)

# %% [markdown]
# ## Task 11
# ![image.png](attachment:ea12846d-754f-4d00-a0fe-47d0b7894f62.png)

# %% [markdown]
# ```python
# # Импортируйте библиотеку PyTorch.
# import sys
# import torch
#
# # Создайте тензор.
# list_in = str_to_list(sys.stdin.read())
# tensor = torch.tensor(list_in, dtype=torch.float32, requires_grad=True)

# %% [markdown]
# ## Task 12
# ![image.png](attachment:e672713c-72f9-4a79-9a23-2b813e841511.png)

# %%
# Создайте тензоры и запишите в переменные tensor_ones и tensor_zeros.
import torch

tensor_ones = torch.ones(size=(7, 2, 3))
tensor_zeros = torch.zeros(size=(7, 2, 3))

# %% [markdown]
# ## Task 13
# ![image.png](attachment:783a646e-4a84-4300-b9c1-7411fb825991.png)

# %%
tensor = torch.tensor([[1., 2., 3.], [4., 5., 6.]], dtype=torch.float64)

# %%
# Тензор создан и записан в переменную tensor.
tensor_zs = torch.zeros_like(input=tensor)
tensor_ns = torch.ones_like(input=tensor)

# %% [markdown]
# ## Task 14
# ![image.png](attachment:ee2bd158-121a-449c-90f6-25de0b73ae77.png)

# %%
# Тензор создан и записан в переменную tensor.
tensor = torch.reshape(input=tensor, shape=(2, 2, 2))

# %% [markdown]
# ## Task 15
# ![image.png](attachment:29496618-3d7c-4855-86b5-5e4ca14d4a10.png)

# %%
# Тензор создан и записан в переменную tensor.
new_tensor = torch.reshape(input=tensor, shape=(64, 1, 28, 28))

# %% [markdown]
# ## Task 16
# ![image.png](attachment:5efc477e-68b4-4e54-accc-34489d470385.png)

# %%
# Тензор создан и записан в переменную tensor.
new_tensor = torch.unsqueeze(input=tensor, dim=-1)
