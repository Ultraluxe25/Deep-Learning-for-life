# %% [markdown]
# ![image.png](attachment:9ff20dac-398e-4bb2-be38-b8a401d4c12e.png)
# ### Автор курса вдохновлялся работой Балакирева и Разинкова

# %% [markdown]
# ![image.png](attachment:1e7b4036-9a3f-4911-b7e7-d9fd4751f554.png)
# ### Библиотеки для курса

# %% [markdown]
# ![image.png](attachment:ebcd036c-a1b9-452a-83dc-5f50dc3de28c.png)
# ### Эти уроки были обещаны автором, но отсутствуют :(

# %% [markdown]
# ![image.png](attachment:1c010f61-4e9d-41ca-9f3e-1569fb4e71f5.png)

# %% [markdown]
# ![image.png](attachment:0e1b06d6-f1ac-4f11-8c86-3f5514f40fc1.png)
# ### Задача сегментации - выявить маску объекта

# %% [markdown]
# ### Сергей рекомендует брать размер валидационной выборки равный 10% от тренировочной

# %% [markdown]
# ![image.png](attachment:a7e00270-816b-49a1-8b89-61714e0dbc0f.png)
# ### Также очень важно правильно подобрать функцию потерь и оптимизатор

# %% [markdown]
# ![image.png](attachment:57ef378c-f35b-4810-b626-eddf1b014561.png)

# %% [markdown]
# ![image.png](attachment:fc8d5795-5595-48a1-b781-f4d230535eda.png)

# %% [markdown]
# ![image.png](attachment:b9d472b7-ff3f-4538-a376-108f938a0cf3.png)

# %% [markdown]
# ```Python
# # Тензор создан и записан в переменную tensor.
# tensor = torch.reshape(input=tensor, shape=(2, 2, 2))
# ```

# %% [markdown]
# ![image.png](attachment:51e1eafb-b412-4361-bb54-95f3319abd43.png)

# %% [markdown]
# ![image.png](attachment:06adf7a3-1246-49c1-9b1f-01aaf317fa31.png)
# ```python
# import numpy as np
#
# # Тензор создан и записан в переменную tensor.
# new_tensor = tensor[:, np.newaxis, :, :]
# ```

# %% [markdown]
# ![image.png](attachment:5463c8a9-11c6-4fba-acc5-8aa4e7749630.png)

# %% [markdown]
# ### При использовании операции конкатенация в методе forward НЕЛЬЗЯ объединять тензоры по нулевой оси. Эта ось содержит размер batch-а, это значение должно оставаться постоянным во время прямого прохода.

# %% [markdown]
# ### При изменении размера тензора не всегда заранее знаешь какое количество элементов будет на определенной оси. В таком случае количество элементов на этой оси нужно поставить равным "-1".

# %% [markdown]
# ![image.png](attachment:83bfab07-8424-45be-8da5-63529adf7062.png)
