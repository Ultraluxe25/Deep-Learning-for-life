# %% [markdown]
# ![image.png](attachment:a0940f48-783f-43c9-94f1-f7a67fa7a600.png)

# %% [markdown]
# ![image.png](attachment:3377ed61-8405-43ab-861d-018828e60702.png)

# %% [markdown]
# ![image.png](attachment:995b3da7-4acb-4bbb-ad31-1381a2b4d502.png)

# %% [markdown]
# ![image.png](attachment:4b91e2f8-43d2-4a05-bfc7-3548e61fcb45.png)

# %% [markdown]
# # LeNet-5

# %% [markdown]
# ![image.png](attachment:c42adec7-0c03-4a82-8117-83c42141f0d1.png)

# %% [markdown]
# ### Каждое ядро свертки (их 6 на первом слое) используется для поиска разных признаков изображений

# %% [markdown]
# ![image.png](attachment:620dc989-9ad0-46d2-a356-45e73544b334.png)
# ### На разных слоях модель выделяет разные признаки
