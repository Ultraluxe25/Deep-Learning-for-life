# %% [markdown]
# ![image.png](attachment:c3e13c01-eb38-4dc4-9f12-3b966b82573a.png)

# %% [markdown]
# ![image.png](attachment:b02fd61e-010f-4631-b244-d81dde984899.png)

# %% [markdown]
# ![image.png](attachment:c86356f6-7897-40c9-8842-6f5623b1eb38.png)

# %% [markdown]
# ![image.png](attachment:1923cd5e-0fb4-4430-be59-8de0be95f0ef.png)

# %% [markdown]
# ![image.png](attachment:57b01b96-519b-4806-a596-9b1b26c95421.png)

# %% [markdown]
# ![image.png](attachment:0dc27fe0-3ee8-4a6a-9458-f23bb8bd76b4.png)
