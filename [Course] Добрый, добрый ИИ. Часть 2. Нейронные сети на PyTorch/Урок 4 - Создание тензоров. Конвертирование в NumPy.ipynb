# %% [markdown]
# ![image.png](attachment:6617852d-2e51-48c6-a9b4-aa5f32da2cf9.png)

# %% [markdown]
# ![image.png](attachment:6268575e-80fd-4af9-9aef-e91fd8f6e304.png)

# %%
import torch

# %%
t = torch.Tensor(3, 5, 2)
t
# Out:
# tensor([[[3.7800e+22, 1.3256e-42],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]]])

# %%
# In new PyTorch versions
t = torch.empty(size=(3, 5, 2))
t
# Out:
# tensor([[[3.7801e+22, 1.3256e-42],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00]]])

# %%
t.dtype
# Out:
# torch.float32

# %%
a = torch.empty(2, dtype=torch.int64)
a.dtype
# Out:
# torch.int64

# %%
torch.tensor(data=[[1, 2], [3, 4], [5, 6]])
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %% [markdown]
# ### Тензор состоящий из многих осей

# %%
t = torch.DoubleTensor(2, 2, 2, 2)
t.shape
# Out:
# torch.Size([2, 2, 2, 2])

# %%
a.type() # Класс от которого был создан
# Out:
# 'torch.LongTensor'

# %%
t.dim()  # Количество осей
# Out:
# 4

# %%
t.size()  # Количество элементов по каждой оси
# Out:
# torch.Size([2, 2, 2, 2])

# %%
import numpy as np

t1 = np.array([[1, 2], [3, 4]])
t2 = torch.from_numpy(t1)
t2
# Out:
# tensor([[1, 2],
#         [3, 4]], dtype=torch.int32)

# %%
t3 = torch.tensor(data=t1, dtype=torch.float64)
t3
# Out:
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %% [markdown]
# ### torch.tensor() делает глубокую копию, а вот torch.from_array() использует исходные данные

# %%
t1[0] = 10
t2
# Out:
# tensor([[10, 10],
#         [ 3,  4]], dtype=torch.int32)

# %%
t1
# Out:
# array([[10, 10],
#        [ 3,  4]])

# %%
a = t3.numpy()  # Неглубокая копия
a
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
b = t3.numpy().copy()  # Глубокая копия
b
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %% [markdown]
# ![image.png](attachment:bd84bdff-21d9-4fe5-ab41-2883896ffa4c.png)

# %% [markdown]
# ![image.png](attachment:f893acf4-bcbc-4e0b-b20f-4df4be9028c1.png)

# %% [markdown]
# ![image.png](attachment:cf9f7a8b-a98a-4af4-9427-d274607ac718.png)
# ![image.png](attachment:2388dca5-1644-4b85-be53-3c08f50a8709.png)

# %% [markdown]
# ![image.png](attachment:912eab62-58f3-405c-ba73-f5354b938753.png)
# ![image.png](attachment:4753a4e8-e695-42f4-bb26-024f0b7c9d04.png)

# %% [markdown]
# ![image.png](attachment:65ce3464-18ff-49cd-a04a-901acb6914ea.png)
# ![image.png](attachment:f5241878-0138-45ca-a0b9-1c4dfea3193e.png)

# %% [markdown]
# ![image.png](attachment:b1271260-967f-4ee1-8181-1d73f426e707.png)
# ![image.png](attachment:12955a4a-fcc2-4e88-a3c1-d943d2f83211.png)

# %% [markdown]
# ![image.png](attachment:410dd0a4-bc42-46e5-896b-da71f7a63045.png)
# ![image.png](attachment:8e57d8c1-e724-49b5-b744-00d1f8fc2681.png)

# %%
A = torch.tensor([[0.2, -1.2, 1.2], [-1.0, -2.0, 1.0], [0.5, 0.2, -0.1]])
B = torch.tensor([[-1.0, 2.1, 0.1], [0.9, 0.8, -2.0], [1.5, -2.0, 0.1]])
tr = torch.stack(tensors=(A, B), dim=0)
tr
# Out:
# tensor([[[ 0.2000, -1.2000,  1.2000],
#          [-1.0000, -2.0000,  1.0000],
#          [ 0.5000,  0.2000, -0.1000]],
#
#         [[-1.0000,  2.1000,  0.1000],
#          [ 0.9000,  0.8000, -2.0000],
#          [ 1.5000, -2.0000,  0.1000]]])

# %% [markdown]
# ![image.png](attachment:53f005f9-92d5-448b-952a-5caed6f59b92.png)
# ![image.png](attachment:dcab075b-2d0f-45a1-a09c-5c78c16ac2fc.png)

# %% [markdown]
# ![image.png](attachment:5a4671a1-572f-4654-a385-1996ecf20577.png)
# ![image.png](attachment:509d5095-ae65-4f69-8e93-5df64472769d.png)

# %% [markdown]
# ![image.png](attachment:bc4631d5-db09-47c4-a642-b1e8ea8403c9.png)

# %% [markdown]
# ![image.png](attachment:54b18a5b-0df2-4bc1-9f9d-732a64e05a92.png)

# %%
import numpy as np
import torch

lst = [1, 2, 3, 4, 5, 6]  # lst = list(map(int, input().split()))  # список в программе не менять
arr = np.array(lst).reshape((2, 3))
t_indx = torch.tensor(data=arr, dtype=torch.int64)
t_indx
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %% [markdown]
# ![image.png](attachment:abe10a58-3398-43c1-a8bb-532d2b08ee00.png)
# ![image.png](attachment:e82d760a-da10-4bbd-ae95-4258b233537e.png)
