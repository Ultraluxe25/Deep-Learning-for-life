# %% [markdown]
# ![image.png](attachment:58c62694-ab8a-4fda-b47d-9976abc2a530.png)

# %%
import torch

torch.__version__
# Out:
# '2.4.1+cpu'

# %% [markdown]
# ![image.png](attachment:f411ad2d-164d-40c3-a182-e930273f164d.png)

# %% [markdown]
# ![image.png](attachment:399618b7-a9cf-4e8a-989e-0528436e1442.png)

# %% [markdown]
# ![image.png](attachment:00799c9e-9744-4979-bdb3-2a58321fd0a7.png)
