# %% [markdown]
# # ![image.png](attachment:image.png) Рекуррентные сети в NLP и приложениях

# %% [markdown]
# # Recap

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lesson 1: TF-IDF, word2vec, bag of words and etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ### Простым языком, мешок слов - это частотный словарь.

# %% [markdown]
# Имеется корпус из 10К+ уникальных слов.
# На вход подается текст, и формируется словарь, где ключи - слова из текста,
# присутствующие в корпусе, а значения - количество их вхождений в текст.

# %% [markdown]
# ## Векторизация - это перевод сложного объекта в числовой формат (текста в числа, звуков в числа, изображения в числа).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Мешок слов в Python

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### N-граммы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Недостатки мешка слов

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 5. Не учитываем важность слов
#
# 6. N-граммы приводят к переобучению

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Обычно больше N=3 уже не используют чтобы не переобучить модель
